# %%
import pandas as pd
import matplotlib.pyplot as plt
from matplotlib.lines import Line2D
import matplotlib.colors as colors
from matplotlib.ticker import LogLocator, LogFormatterMathtext
import numpy as np
import matplotlib as mpl
from matplotlib.patches import Patch

# %%
data = pd.read_csv("./BoOST_1.dat", sep=r"\s+")

fig, ax = plt.subplots(figsize=(3, 2))

num_false = (data['has_nan'] == True).sum()
total_rows = len(data)

case_colors = {
    True: 'black',  ## There are NaN
    False: 'yellow'  ## No NaN
}

primary_mass = data['primary_mass']
period = data['period']

colors = data['has_nan'].map(case_colors)
    
ax.scatter(primary_mass , period, color=colors, marker='.')


# Write text on the figure
ax.text(
    1.5, 0.0001,
    f'NaN: {num_false}\nTotal rows: {total_rows}',
    transform=ax.transAxes,
    verticalalignment='bottom',
    
)


ax.set_xlabel(r'Mass of primary $/M_\odot$')        # initial (ZAMS) mass
ax.set_ylabel('Orbital period / days')      # final remnant mass
# ax.set_ylim(ymin=1, ymax=10000) ##10000
# ax.set_xlim(xmin=10, xmax=40) ##40

ax.set_box_aspect(1)

# X padding (linear)
ax.set_xlim(10 - 2, 40 + 2)

# Y padding (log scale)
ax.set_yscale('log')
ax.set_ylim(1 / 2, 10000 * 2)

ax.set_xticks([10, 20, 30, 40])
ax.set_yticks([1, 10, 100, 1000, 10000])

plt.show()

ax.set_title('BoOST_run1') 


img_title = "Check_BoOST"

# save_name = output_img_dir/f"{img_title}.png"
save_name = f"{img_title}.png"

fig.savefig(save_name, bbox_inches="tight")

# %%
unique_vals_num_of_lines_true = sorted(data.loc[data['has_nan']== True, 'num_of_lines'].unique())
unique_vals_num_of_lines_true = [int(x) for x in unique_vals_num_of_lines_true]

print("unique_vals_num_of_lines_true", unique_vals_num_of_lines_true)

print(" ")

unique_vals_num_of_lines_false = sorted(data.loc[data['has_nan']== False, 'num_of_lines'].unique())
unique_vals_num_of_lines_false = [int(x) for x in unique_vals_num_of_lines_false]

print("unique_vals_num_of_lines_false", unique_vals_num_of_lines_false)
# Out:
# unique_vals_num_of_lines_true [41, 43, 44, 45, 46, 54, 69, 71, 76, 77, 78, 79, 81, 82, 83, 84, 86, 88, 89, 90, 92, 93, 94, 95, 96, 97, 98, 100, 101, 103, 106, 107, 108, 109, 111, 112, 115, 127, 2705, 2959]
#
# unique_vals_num_of_lines_false [2624, 2625, 2627, 2628, 2629, 2630, 2631, 2655, 2712, 2728, 2909, 2931, 3000, 3046, 3133, 3170, 3174, 3218, 3245, 3246, 3283, 3284, 3294, 3295, 3303, 3304, 3305, 3306, 3316, 3317, 3325, 3326, 3333, 3334, 3372, 3379, 3388, 3389, 3397, 3398, 3418, 3433, 3444, 3454, 3461, 3517, 3532, 3538, 3540, 3548, 3553, 3555, 3566, 3573, 3580, 3581, 3591, 3599, 3619, 3639, 3702, 3740, 3825, 3841, 3850, 3860, 3863, 3864, 3872, 3873, 3882, 3887, 3913, 3917, 3943, 4115, 4249, 4363, 4470, 4503, 4517, 4534, 4537, 4549, 4551, 4556, 4558, 4870, 5427, 5431, 5436, 5439, 5441, 5444, 5447, 5452, 5455, 5456, 5458, 5459, 5460, 5466, 5469, 5470, 5472, 5476, 5478, 5479, 5481, 5482, 5487, 5490, 5491, 5493, 5494, 5498, 5501, 5503, 5504, 5505, 5508, 5509, 5511, 5512, 5513, 5518, 5519, 5521, 5524, 5525, 5526, 5527, 5528, 5532, 5535, 5537, 5538, 5540, 5541, 5543, 5545, 5546, 5547, 5548, 5550, 5552, 5553, 5554, 5555, 5556, 5558, 5559, 5560, 5561, 5562, 5565, 5567, 5568, 5579, 5580, 5589, 5592, 5598, 5600, 5608, 5611, 15643, 15644, 15645, 15653, 15654, 15663, 15670, 15673, 15674, 15675, 15678, 15679, 15686, 15689, 15690, 15691, 15692, 15693, 15696, 15697, 15698, 15699, 15702, 15703, 15704, 15710, 15713, 15715, 15718, 15724, 15781, 15787, 15789, 15792, 15895, 15896, 15901, 15902, 15931, 15934, 15936, 15942, 15959, 16065, 16066, 16094, 16103, 16107, 16110, 16156, 16593, 16597, 16599, 16601, 16603, 16604, 16614, 16623, 16629, 16632, 16637, 16639, 16642, 16649, 16654, 16659, 16666, 16669, 16672, 16681, 16685, 16686, 16694, 16697, 16703, 16711, 16712, 16714, 16720, 16721, 16724, 16728, 16731, 16738, 16739, 16744, 16745, 16746, 16749, 16754, 16757, 16763, 16764, 16765, 16766, 16768, 16771, 16774, 16779, 16781, 16784, 16787, 16791, 16794, 16797, 16800, 16801, 16808, 16815, 16822, 16831, 16881, 16895, 16902, 16904, 16913, 16916, 16923, 16924, 16925, 16936, 16942, 16947, 16950, 16953, 16954, 16957, 16958, 16960, 16961, 16967, 16972, 17086, 17090, 17102, 17106, 17109, 17127, 17129, 17141, 17146, 17150, 17154, 17156, 17178, 17183, 17184, 17188, 17193, 17210, 17212, 17251, 17262, 17269, 17335, 17394, 17440, 17461, 17510, 17524, 17527, 17652, 17653, 17657, 17712, 17724, 17785, 17792, 17793, 17805, 17819, 17841, 17852, 17857, 17868, 17869, 17876, 17884, 17887, 17888, 17891, 17895, 17896, 17901, 17903, 17904, 17906, 17907, 17908, 17909, 17910, 17912, 17913, 17914, 17915, 17917, 17918, 17920, 17922, 17923, 17924, 17927, 17928, 17929, 17930, 17937, 17953, 17994, 18006, 18017, 18018, 18020, 18021, 18022, 18023, 18024, 18026, 18028, 18029, 18030, 18031, 18032, 18033, 18035, 18047, 18049, 18051, 18052, 18053, 18054, 18055, 18057, 18060, 18062, 18063, 18064, 18065, 18067, 18068, 18069, 18070, 18071, 18072, 18073, 18074, 18075, 18076, 18077, 18078]

# %%
data = pd.read_csv("./BoOST_1.dat", sep=r"\s+")

fig, ax = plt.subplots(figsize=(3, 2))

bins = [0, 100, 200, 2500, 3000, 4000, 5000, 6000, 15500, 16500, 18100]

range_colors = [
    'gold',
    'red',
    'blue',
    'lime',
    'magenta',
    'cyan',
    'black',
    'green',
    'brown',
    'gray'
]

point_colors = pd.cut(
    data['num_of_lines'],
    bins=bins,
    labels=range_colors,
    include_lowest=True
)

ax.scatter(
    data['primary_mass'],
    data['period'],
    color=point_colors,
    marker='.'
)



legend_handles = []

for i, color in enumerate(range_colors):

    if bins[i+1] == float('inf'):
        label = f'>{bins[i]}'
    else:
        label = f'{bins[i]}-{bins[i+1]}'

    legend_handles.append(
        Patch(facecolor=color, label=label)
    )

ax.legend(
    handles=legend_handles,
    title='Num_of_lines',
    bbox_to_anchor=(1.05, 1),
    loc='upper left'
)

ax.set_xlabel(r'Mass of primary $/M_\odot$')        # initial (ZAMS) mass
ax.set_ylabel('Orbital period / days')      # final remnant mass
# ax.set_ylim(ymin=1, ymax=10000) ##10000
# ax.set_xlim(xmin=10, xmax=40) ##40

ax.set_box_aspect(1)

# X padding (linear)
ax.set_xlim(10 - 2, 40 + 2)

# Y padding (log scale)
ax.set_yscale('log')
ax.set_ylim(1 / 2, 10000 * 2)

ax.set_xticks([10, 20, 30, 40])
ax.set_yticks([1, 10, 100, 1000, 10000])

plt.show()

ax.set_title('BoOST_run1_num_of_lines') 


img_title = "Check_BoOST_num_of_lines"

# save_name = output_img_dir/f"{img_title}.png"
save_name = f"{img_title}.png"

fig.savefig(save_name, bbox_inches="tight")

# %%
data = pd.read_csv("./BoOST_1.dat", sep=r"\s+")

fig, ax = plt.subplots(figsize=(3, 2))

bins = [0, 100, 200, 2500, 3000, 4000, 5000, 6000, 15500, 16500, 18100]

range_colors = [
    'gold',
    'red',
    'blue',
    'lime',
    'magenta',
    'cyan',
    'black',
    'green',
    'brown',
    'gray'
]

point_colors = pd.cut(
    data['num_of_lines'],
    bins=bins,
    labels=range_colors,
    include_lowest=True
)

mask = data['has_nan']

# False -> highlighted
ax.scatter(
    data.loc[~mask, 'primary_mass'],
    data.loc[~mask, 'period'],
    color=point_colors[~mask],
    marker='.',
    alpha=1
)

# True -> faded
ax.scatter(
    data.loc[mask, 'primary_mass'],
    data.loc[mask, 'period'],
    color=point_colors[mask],
    marker='.',
    alpha=0.00001
)


from matplotlib.patches import Patch

legend_handles = []

for i, color in enumerate(range_colors):

    if bins[i+1] == float('inf'):
        label = f'>{bins[i]}'
    else:
        label = f'{bins[i]}-{bins[i+1]}'

    legend_handles.append(
        Patch(facecolor=color, label=label)
    )

ax.legend(
    handles=legend_handles,
    title='Num_of_lines',
    bbox_to_anchor=(1.05, 1),
    loc='upper left'
)

ax.set_xlabel(r'Mass of primary $/M_\odot$')        # initial (ZAMS) mass
ax.set_ylabel('Orbital period / days')      # final remnant mass
# ax.set_ylim(ymin=1, ymax=10000) ##10000
# ax.set_xlim(xmin=10, xmax=40) ##40

ax.set_box_aspect(1)

# X padding (linear)
ax.set_xlim(10 - 2, 40 + 2)

# Y padding (log scale)
ax.set_yscale('log')
ax.set_ylim(1 / 2, 10000 * 2)

ax.set_xticks([10, 20, 30, 40])
ax.set_yticks([1, 10, 100, 1000, 10000])

plt.show()

ax.set_title('BoOST_run1_num_of_lines_with_mask_true_faded') 


img_title = "Check_BoOST_num_of_lines_with_mask_true_faded"

# save_name = output_img_dir/f"{img_title}.png"
save_name = f"{img_title}.png"

fig.savefig(save_name, bbox_inches="tight")

# %%
data = pd.read_csv("./BoOST_1.dat", sep=r"\s+")

fig, ax = plt.subplots(figsize=(3, 2))

bins = [0, 100, 200, 2500, 3000, 4000, 5000, 6000, 15500, 16500, 18100]

range_colors = [
    'gold',
    'red',
    'blue',
    'lime',
    'magenta',
    'cyan',
    'black',
    'green',
    'brown',
    'gray'
]

point_colors = pd.cut(
    data['num_of_lines'],
    bins=bins,
    labels=range_colors,
    include_lowest=True
)

mask = data['has_nan']

# False -> faded
ax.scatter(
    data.loc[~mask, 'primary_mass'],
    data.loc[~mask, 'period'],
    color=point_colors[~mask],
    marker='.',
    alpha=0.00001
)

# True -> highlighted
ax.scatter(
    data.loc[mask, 'primary_mass'],
    data.loc[mask, 'period'],
    color=point_colors[mask],
    marker='.',
    alpha=1
)


from matplotlib.patches import Patch

legend_handles = []

for i, color in enumerate(range_colors):

    if bins[i+1] == float('inf'):
        label = f'>{bins[i]}'
    else:
        label = f'{bins[i]}-{bins[i+1]}'

    legend_handles.append(
        Patch(facecolor=color, label=label)
    )

ax.legend(
    handles=legend_handles,
    title='Num_of_lines',
    bbox_to_anchor=(1.05, 1),
    loc='upper left'
)

ax.set_xlabel(r'Mass of primary $/M_\odot$')        # initial (ZAMS) mass
ax.set_ylabel('Orbital period / days')      # final remnant mass
# ax.set_ylim(ymin=1, ymax=10000) ##10000
# ax.set_xlim(xmin=10, xmax=40) ##40

ax.set_box_aspect(1)

# X padding (linear)
ax.set_xlim(10 - 2, 40 + 2)

# Y padding (log scale)
ax.set_yscale('log')
ax.set_ylim(1 / 2, 10000 * 2)

ax.set_xticks([10, 20, 30, 40])
ax.set_yticks([1, 10, 100, 1000, 10000])

plt.show()

ax.set_title('BoOST_run1_num_of_lines_with_mask_false_faded') 


img_title = "Check_BoOST_num_of_lines_with_mask_false_faded"

# save_name = output_img_dir/f"{img_title}.png"
save_name = f"{img_title}.png"

fig.savefig(save_name, bbox_inches="tight")

# %%
bse.f describes all input parameters. 

*
* Set the collision matrix.
*
      CALL instar
*
      label(1) = 'INITIAL '  # start
      label(2) = 'KW CHNGE'  # kw change
      label(3) = 'BEG RCHE'
      label(4) = 'END RCHE'
      label(5) = 'CONTACT '  # Contact system
      label(6) = 'COELESCE'  # Merged (evolv2.f)
      label(7) = 'COMENV  '
      label(8) = 'GNTAGE  '  # determine the age of a giant from its core mass and type (SSE/SSE_gntage.f)
      label(9) = 'NO REMNT' # Binary dissolved by a supernova or tides. (evolv2.f)
      label(10) = 'MAX TIME'
      label(11) = 'DISRUPT '
      label(12) = 'BEG SYMB'
      label(13) = 'END SYMB'
      label(14) = 'BEG BSS' # blue straggler formation. (evolv2.f)
*

evolv2.f >> 4) Now using q_crit = 3.0 for MS-MS Roche systems (previously we 
*    had nothing). This corresponds roughly to R proportional to M^5 
*    which should be true for the majority of the MS (varies from 
*    (M^17 -> M^2). If q > q_crit then contact occurs. 
*    For CHeB primaries we also take q_crit = 3.0 and allow 
*    common-envelope to occur if this is exceeded.

# %% [markdown]
# ##Run 2

# %%
data = pd.read_csv("./BoOST_1_run2.dat", sep=r"\s+")

fig, ax = plt.subplots(figsize=(3, 2))

num_false = (data['has_nan'] == True).sum()
total_rows = len(data)

case_colors = {
    True: 'black',
    False: 'yellow'  ## No NaN
}

primary_mass = data['primary_mass']
period = data['period']

colors = data['has_nan'].map(case_colors)
    
ax.scatter(primary_mass , period, color=colors, marker='.')


# Write text on the figure
ax.text(
    1.5, 0.0001,
    f'NaN: {num_false}\nTotal rows: {total_rows}',
    transform=ax.transAxes,
    verticalalignment='bottom',
    
)


ax.set_xlabel(r'Mass of primary $/M_\odot$')        # initial (ZAMS) mass
ax.set_ylabel('Orbital period / days')      # final remnant mass
# ax.set_ylim(ymin=1, ymax=10000) ##10000
# ax.set_xlim(xmin=10, xmax=40) ##40

ax.set_box_aspect(1)

# X padding (linear)
ax.set_xlim(10 - 2, 40 + 2)

# Y padding (log scale)
ax.set_yscale('log')
ax.set_ylim(1 / 2, 10000 * 2)

ax.set_xticks([10, 20, 30, 40])
ax.set_yticks([1, 10, 100, 1000, 10000])

plt.show()

ax.set_title('BoOST_run2') 


img_title = "Check_BoOST_run2"

# save_name = output_img_dir/f"{img_title}.png"
save_name = f"{img_title}.png"

fig.savefig(save_name, bbox_inches="tight")
