# %% [markdown]
# # Trial run for seperate parts to prepare the plot with (61* 41) systems

# %%
import numpy as np
import matplotlib as mpl
import matplotlib.pyplot as plt
import os
from pathlib import Path
import pandas as pd
import json

# %%
m1 = 13.4896  # 22.4827
m2 = m1/0.6
p = 2511.886431509582

print(m2)

content = f"""{m1}  {m2}    13700 {p}  1 1 0.02 0.0
0.5 0.0 1.0 3.0 0.5
0 1 0 1 0 2 3.0 29769
0.001 0.01 0.02
0.0 0.125 1.0 1.5 0.001 10.0 -1.0
1
"""

with open("binary.in", "w") as f:
    f.write(content)

# !/home/poornima/Documents/BSE_METISSE_project/bse_metisse
# Out:
# 22.482666666666667
#
#  METALLICITY_DIR: /home/poornima/Documents/BSE_METISSE_project/BoOST/
#  METALLICITY_DIR_HE: /home/poornima/Documents/BSE_METISSE_project/sample_tracks_solarZ/Helium
#  Input Z is :  2.00000E-02
#  Reading naked helium star tracks
#  Found matching Z_files   2.00000E-02
#  Found           33  tracks.
#  Minimum initial mass    0.4
#  Maximum initial mass  148.8
#  Reading main (hydrogen star) tracks
#  Found matching Z_files   8.00000E-03
#  Found           10  tracks.
#  Minimum initial mass    9.0
#  Maximum initial mass  498.8
#       TIME      M1       M2   K1 K2        SEP    ECC  R1/ROL1 R2/ROL2  TYPE
#      0.0000   13.490   22.483  1  1     2566.105  0.00   0.005   0.005  INITIAL
#      8.2012   14.483   21.002  1  2          NaN   NaN     NaN     NaN  KW CHNGE
#      8.2376   14.518   20.959  1  4          NaN   NaN     NaN     NaN  KW CHNGE
#      8.7643   20.947   12.907  1  4          NaN   NaN     NaN     NaN  BEG BSS
#      8.8430   21.751    8.575  1 14        0.000  0.00InfinityInfinity  KW CHNGE
#     11.6277   20.952    9.215  2 14          NaN   NaN     NaN     NaN  KW CHNGE
#     11.6643   20.909    9.249  4 14          NaN   NaN     NaN     NaN  KW CHNGE
#     12.2721    8.522   16.414 14 14        0.000  0.00InfinityInfinity  KW CHNGE
#  13700.0000    8.522   16.414 14 14          NaN   NaN     NaN     NaN  MAX TIME
#
# Note: The following floating-point exceptions are signalling: IEEE_INVALID_FLAG IEEE_DIVIDE_BY_ZERO IEEE_OVERFLOW_FLAG IEEE_UNDERFLOW_FLAG IEEE_DENORMAL

# %%
m2 = 10.23373892/0.6
m1_str = f"{int(10.23373892 * 100):05d}"
m2_str  = f"{int(m2 * 100):05d}"

file_name = f"{m1_str}M_{m2_str}M.dat"
file_name
# Out:
# '01023M_01705M.dat'

# %%
m1 = 2.0  # 22.4827
m2 = 1.0
p = 2511.886431509582

print(m2)

content = f"""{m1}  {m2}    13700 {p}  1 1 0.02 0.0
0.5 0.0 1.0 3.0 0.5
0 1 0 1 0 2 3.0 29769
0.001 0.01 0.02
0.0 0.125 1.0 1.5 0.001 10.0 -1.0
1
"""

with open("binary.in", "w") as f:
    f.write(content)

# !/home/poornima/Documents/BSE_METISSE_project/bse_metisse
# Out:
# 1.0
#
#  METALLICITY_DIR: /home/poornima/Documents/BSE_METISSE_project/BoOST/
#  METALLICITY_DIR_HE: /home/poornima/Documents/BSE_METISSE_project/sample_tracks_solarZ/Helium
#  Input Z is :  2.00000E-02
#  Reading naked helium star tracks
#  Found matching Z_files   2.00000E-02
#  Found           33  tracks.
#  Minimum initial mass    0.4
#  Maximum initial mass  148.8
#  Reading main (hydrogen star) tracks
#  Found matching Z_files   8.00000E-03
#  Found           10  tracks.
#  Minimum initial mass    9.0
#  Maximum initial mass  498.8
#       TIME      M1       M2   K1 K2        SEP    ECC  R1/ROL1 R2/ROL2  TYPE
#      0.0000    9.000    9.000  1  1        4.102  0.00   2.251   2.251  INITIAL
#      0.0000    9.000    9.000  1  1        4.102  0.00   2.251   2.251  BEG RCHE
#      0.0001    8.997    9.002  1  1        3.623  0.00   2.548   2.547  CONTACT
#      0.0001   17.999    9.002  1 15        0.000  0.00   0.000  -1.000  COELESCE
#     10.5882   17.316    0.000  2 15        0.000 -1.00   0.000  -1.000  KW CHNGE
#     10.6495   17.288    0.000  4 15        0.000 -1.00   0.000  -1.000  KW CHNGE
#     11.4341    1.853    0.000 13 15        0.000 -1.00   0.000  -1.000  KW CHNGE
#  13700.0000    1.853    0.000 13 15        0.000 -1.00   0.000  -1.000  MAX TIME
#
# Note: The following floating-point exceptions are signalling: IEEE_INVALID_FLAG

# %%
path = "/home/poornima/Documents/BSE_METISSE_project/output_binary/"
file_name = "00200M_00100M.dat"
full_path = os.path.join(path, file_name)

data = np.loadtxt(full_path) 

# Remove the last row
data = data[:-1, :]

# Define the column names
columns = [
    "Time",
    "stellar_type_1","stellar_type_2","initial_mass_1","initial_mass_2", "current_mass_1","current_mass_2","log10_r_1","log10_r_2",
    "R1/ROL1","R2/ROL2","log10_L_1","log10_L_2",
    "spin_1","spin_2","mass_loss_rate_1","mass_loss_rate_2","convective_envelope_mass_1","convective_envelope_mass_2",
    "envelope_radius_1","envelope_radius_2","sep_Rsun","ecc"]
    
df = pd.DataFrame(data, columns=columns)

df.head()


# Primary star - see RLOF time and primary star's ev. state
mask_primary = df["R1/ROL1"] >= 1
if mask_primary.any():  # only if there is at least one True
    RLOF_time_primary = df["Time"][mask_primary].min()
    RLOF_ev_state_primary = df[df["Time"] == RLOF_time_primary]["stellar_type_1"].iloc[0]
    print(RLOF_time_primary,RLOF_ev_state_primary)
else:
    RLOF_time_primary = np.nan

# Secondary star - see RLOF time and secondary star's ev. state
mask_secondary = df["R2/ROL2"] >= 1
if mask_secondary.any():
    RLOF_time_secondary = df["Time"][mask_secondary].min()
    RLOF_ev_state_secondary = df[df["Time"] == RLOF_time_secondary]["stellar_type_2"].iloc[0]
    print(RLOF_time_secondary,RLOF_ev_state_secondary)
else:
    RLOF_time_secondary = np.nan

###print(df.iloc[1])

### see which star goes through RLOF first and make that star the donar star 
if RLOF_time_primary < RLOF_time_secondary :
    donar_state = RLOF_ev_state_primary
elif RLOF_time_primary > RLOF_time_secondary :
    donar_state = RLOF_ev_state_secondary
elif RLOF_time_primary == RLOF_time_secondary :
    donar_state = RLOF_ev_state_primary
elif np.isnan(RLOF_time_primary) and np.isnan(RLOF_time_secondary):
    donar_state = np.nan
elif np.isnan(RLOF_time_primary):
    donar_state = RLOF_ev_state_secondary
elif np.isnan(RLOF_time_secondary):
    donar_state = RLOF_ev_state_primary

print(donar_state)
# Out:
# 0.0 1.0
# 0.0 1.0
# 1.0

# %%
subset_after_twelve_gyr = df[df["Time"] > 12000]

if not subset_after_twelve_gyr.empty:
    sep_12_gyr = float(subset_after_twelve_gyr["sep_Rsun"].iloc[0])
else:
    sep_12_gyr = np.nan  
    
sep_12_gyr
# Out:
# 0.0

# %%
masses = np.logspace(np.log10(10), np.log10(40), 61)

print(masses)
# Out:
# [10.         10.23373892 10.47294123 10.71773463 10.9682498  11.22462048
#  11.48698355 11.75547906 12.03025036 12.31144413 12.5992105  12.89370308
#  13.19507911 13.50349946 13.8191288  14.14213562 14.47269237 14.81097552
#  15.15716567 15.51144762 15.87401052 16.24504793 16.62475792 17.01334322
#  17.41101127 17.81797436 18.23444977 18.66065983 19.09683208 19.54319937
#  20.         20.46747784 20.94588246 21.43546925 21.93649959 22.44924097
#  22.9739671  23.51095813 24.06050072 24.62288827 25.198421   25.78740617
#  26.39015822 27.00699892 27.6382576  28.28427125 28.94538475 29.62195105
#  30.31433133 31.02289524 31.74802104 32.49009585 33.24951585 34.02668644
#  34.82202253 35.63594873 36.46889954 37.32131966 38.19366416 39.08639874
#  40.        ]

# %%
len(masses)
# Out:
# 61

# %%
m1_type_now = 13.0
m2_type_now = 13.0
if {m1_type_now, m2_type_now} == {13.0, 14.0}:
    print("hello")
elif {m1_type_now, m2_type_now} == {13.0}:
    print("nice")
else :
    print("hiii")
# Out:
# nice

# %%
mass = 10 ** np.arange(np.log10(10), np.log10(40), 0.01)

print(len(mass))
print(mass)
# Out:
# 61
# [10.         10.23292992 10.47128548 10.71519305 10.96478196 11.22018454
#  11.48153621 11.74897555 12.02264435 12.30268771 12.58925412 12.88249552
#  13.18256739 13.48962883 13.80384265 14.12537545 14.45439771 14.79108388
#  15.13561248 15.48816619 15.84893192 16.21810097 16.59586907 16.98243652
#  17.37800829 17.7827941  18.19700859 18.62087137 19.05460718 19.498446
#  19.95262315 20.41737945 20.89296131 21.3796209  21.87761624 22.38721139
#  22.90867653 23.44228815 23.98832919 24.54708916 25.11886432 25.70395783
#  26.30267992 26.91534804 27.54228703 28.18382931 28.84031503 29.51209227
#  30.1995172  30.90295433 31.6227766  32.35936569 33.11311215 33.88441561
#  34.67368505 35.48133892 36.30780548 37.15352291 38.01893963 38.9045145
#  39.81071706]

# %%
groups = np.array_split(mass, 6)

# %%
group1 = groups[0]

group1
# Out:
# array([10.        , 10.23292992, 10.47128548, 10.71519305, 10.96478196,
#        11.22018454, 11.48153621, 11.74897555, 12.02264435, 12.30268771,
#        12.58925412])

# %%
for m1 in groups[0]:
    print(m1)
# Out:
# 10.0
# 10.232929922807541
# 10.471285480508996
# 10.715193052376065
# 10.964781961431852
# 11.220184543019636
# 11.481536214968829
# 11.748975549395297
# 12.02264434617413
# 12.302687708123818
# 12.589254117941675

# %%
mass = 10 ** np.arange(np.log10(12.58925412), np.log10(15.7), 0.01)
print(len(mass))
print(mass)
# Out:
# 10
# [12.58925412 12.88249552 13.18256739 13.48962883 13.80384265 14.12537545
#  14.45439771 14.79108388 15.13561249 15.48816619]

# %%
period = 10 ** np.arange(np.log10(1), np.log10(10001), 0.1)

print(len(period))
print(period)
# Out:
# 41
# [1.00000000e+00 1.25892541e+00 1.58489319e+00 1.99526231e+00
#  2.51188643e+00 3.16227766e+00 3.98107171e+00 5.01187234e+00
#  6.30957344e+00 7.94328235e+00 1.00000000e+01 1.25892541e+01
#  1.58489319e+01 1.99526231e+01 2.51188643e+01 3.16227766e+01
#  3.98107171e+01 5.01187234e+01 6.30957344e+01 7.94328235e+01
#  1.00000000e+02 1.25892541e+02 1.58489319e+02 1.99526231e+02
#  2.51188643e+02 3.16227766e+02 3.98107171e+02 5.01187234e+02
#  6.30957344e+02 7.94328235e+02 1.00000000e+03 1.25892541e+03
#  1.58489319e+03 1.99526231e+03 2.51188643e+03 3.16227766e+03
#  3.98107171e+03 5.01187234e+03 6.30957344e+03 7.94328235e+03
#  1.00000000e+04]

# %%
mass = []
m = 10.0

mass.append(m)

for i in range(61):
    m = m * 10**0.01
    mass.append(m)

print(mass)
print(len(mass))
# Out:
# [10.0, 10.232929922807541, 10.471285480508994, 10.715193052376064, 10.96478196143185, 11.220184543019634, 11.481536214968827, 11.748975549395295, 12.022644346174129, 12.302687708123814, 12.589254117941671, 12.882495516931337, 13.182567385564068, 13.489628825916533, 13.803842646028844, 14.125375446227538, 14.45439770745927, 14.791083881682068, 15.135612484362076, 15.488166189124808, 15.84893192461113, 16.218100973589294, 16.5958690743756, 16.982436524617437, 17.37800828749375, 17.78279410038922, 18.197008586099827, 18.620871366628666, 19.054607179632463, 19.498445997580443, 19.952623149688787, 20.417379446695282, 20.892961308540382, 21.379620895022306, 21.87761623949551, 22.38721138568338, 22.908676527677713, 23.442288153199204, 23.988329190194886, 24.547089156850284, 25.11886431509578, 25.703957827688615, 26.302679918953796, 26.915348039269134, 27.54228703338164, 28.183829312644512, 28.840315031266034, 29.51209226666383, 30.199517204020136, 30.902954325135877, 31.622776601683764, 32.3593656929628, 33.11311214825908, 33.88441561392022, 34.67368504525312, 35.481338923357505, 36.30780547701009, 37.15352290971721, 38.018939632056075, 38.90451449942801, 39.81071705534967, 40.738027780411215]
# 62

# %%
period = []
p = 1.0

period.append(p)

for i in range(40):
    p = p * 10**0.1
    period.append(p)

print(period)
print(len(period))
# Out:
# [1.0, 1.2589254117941673, 1.5848931924611136, 1.99526231496888, 2.5118864315095806, 3.16227766016838, 3.9810717055349736, 5.011872336272725, 6.309573444801935, 7.9432823472428185, 10.000000000000005, 12.58925411794168, 15.848931924611145, 19.95262314968881, 25.118864315095824, 31.622776601683825, 39.81071705534977, 50.11872336272729, 63.0957344480194, 79.43282347242825, 100.00000000000014, 125.89254117941691, 158.4893192461116, 199.52623149688827, 251.18864315095843, 316.2277660168385, 398.10717055349795, 501.1872336272732, 630.9573444801945, 794.3282347242831, 1000.000000000002, 1258.9254117941698, 1584.8931924611168, 1995.2623149688839, 2511.8864315095857, 3162.2776601683863, 3981.0717055349814, 5011.872336272734, 6309.5734448019475, 7943.2823472428345, 10000.000000000025]
# 41

# %%
# ------------------- Read the file and assign column names -------------------------------------------
path = "/home/poornima/Documents/BSE_METISSE_project/output_binary/"
m1_str = f"{int(m1 * 100):05d}"
m2_str  = f"{int(m2 * 100):05d}"
filename = f"{m1_str}M_{m2_str}M.dat"        ## file_name = "00200M_00100M.dat"
full_path = os.path.join(path, file_name)

data = np.loadtxt(full_path) 

# Remove the last row
data = data[:-1, :]

# Define the column names
columns = [
    "Time",
    "stellar_type_1","stellar_type_2","initial_mass_1","initial_mass_2", "current_mass_1","current_mass_2","log10_r_1","log10_r_2",
    "R1/ROL1","R2/ROL2","log10_L_1","log10_L_2",
    "spin_1","spin_2","mass_loss_rate_1","mass_loss_rate_2","convective_envelope_mass_1","convective_envelope_mass_2",
    "envelope_radius_1","envelope_radius_2","sep_Rsun","ecc"]
    
df = pd.DataFrame(data, columns=columns)

#df.head()

# --------------- RLOF -------------------------------------------------------

# Primary star - see RLOF time and primary star's ev. state
mask_primary = df["R1/ROL1"] >= 1
if mask_primary.any():  # only if there is at least one True
    RLOF_time_primary = df["Time"][mask_primary].min()
    RLOF_ev_state_primary = df[df["Time"] == RLOF_time_primary]["stellar_type_1"].iloc[0]
    print(RLOF_time_primary,RLOF_ev_state_primary)
else:
    RLOF_time_primary = np.nan

# Secondary star - see RLOF time and secondary star's ev. state
mask_secondary = df["R2/ROL2"] >= 1
if mask_secondary.any():
    RLOF_time_secondary = df["Time"][mask_secondary].min()
    RLOF_ev_state_secondary = df[df["Time"] == RLOF_time_secondary]["stellar_type_2"].iloc[0]
    print(RLOF_time_secondary,RLOF_ev_state_secondary)
else:
    RLOF_time_secondary = np.nan

###print(df.iloc[1])

### see which star goes through RLOF first and make that star the donar star 
if RLOF_time_primary < RLOF_time_secondary :
    donar_state = RLOF_ev_state_primary
elif RLOF_time_primary > RLOF_time_secondary :
    donar_state = RLOF_ev_state_secondary
elif RLOF_time_primary == RLOF_time_secondary :
    donar_state = RLOF_ev_state_primary
elif np.isnan(RLOF_time_primary) and np.isnan(RLOF_time_secondary):
    donar_state = np.nan
elif np.isnan(RLOF_time_primary):
    donar_state = RLOF_ev_state_secondary
elif np.isnan(RLOF_time_secondary):
    donar_state = RLOF_ev_state_primary

#print(donar_state)

###  Assign case
if donar_state == 1.0:   # MS
    case = 0  # case A
elif donar_state == 2.0 or donar_state == 3.0 :  # HG or FGB
     case = 1 # case B[HG]
elif donar_state == 4.0:  # CHeB
     case = 2  # case B[CHeB]
elif donar_state == 5.0 or donar_state == 6.0:  # First Asymptotic Giant Branch or Second Asymptotic Giant Branch
     case = 3 # case C
elif np.isnan(donar_state) :
     case = 4 # None
else :
     case = 5 # any other state

f1.write(f"{m1} {p} {case} {donar_state}\n")    

# ---------------------------------------------12 Gyr -------------------------------------------------------------------------

subset_after_twelve_gyr = df[df["Time"] > 12000]  ### get subset where time is more than 12 Gyr


### Find the seperation after 12 Gyr
if not subset_after_twelve_gyr.empty:
    sep_12_gyr = float(subset_after_twelve_gyr["sep_Rsun"].iloc[0])
else:
    sep_12_gyr = np.nan  

### Find the type of stars after 12 Gyr
if not subset_after_twelve_gyr.empty:
    m1_type_now = subset_after_twelve_gyr["stellar_type_1"].iloc[0]
    m2_type_now = subset_after_twelve_gyr["stellar_type_2"].iloc[0]
else:
    m1_type_now = np.nan 
    m2_type_now = np.nan 

### Find the situation of the binaries after 12 Gyrs

if sep_12_gyr != 0.0 :
    if {m1_type_now, m2_type_now} == {14.0}: ### BBH
        last_state = 1
    elif {m1_type_now, m2_type_now} == {13.0, 14.0}: ### BH-NS
        last_state = 2
    elif {m1_type_now, m2_type_now} == {13.0} :     ###BNS
        last_state = 3
    elif ((m1_type_now in {10.0, 11.0, 12.0, 13.0, 14.0} and m2_type_now in {10.0, 11.0, 12.0}) or
        (m2_type_now in {10.0, 11.0, 12.0, 13.0, 14.0} and m1_type_now in {10.0, 11.0, 12.0})):      ### WD - Compact Object
        last_state = 4
    elif 0 <= int(m1_type_now) <= 9 and 0 <= int(m2_type_now) <= 9: ### non-double compact objects
        last_state = 5
    elif m1_type_now == 15 or m2_type_now == 15:    ### Massless Supernova
        last_state = 6
elif sep_12_gyr ==0.0 :     ### Mergers
    if {m1_type_now, m2_type_now} == {14.0}: ### BBH
        last_state = 7
    elif {m1_type_now, m2_type_now} == {13.0, 14.0}: ### BH-NS
        last_state = 8
    elif {m1_type_now, m2_type_now} == {13.0} :     ###BNS
        last_state = 9
    elif ((m1_type_now in {10.0, 11.0, 12.0, 13.0, 14.0} and m2_type_now in {10.0, 11.0, 12.0}) or
        (m2_type_now in {10.0, 11.0, 12.0, 13.0, 14.0} and m1_type_now in {10.0, 11.0, 12.0})):      ### WD - Compact Object
        last_state = 10
    elif 0 <= int(m1_type_now) <= 9 and 0 <= int(m2_type_now) <= 9: ### non-double compact objects
        last_state = 11
    elif m1_type_now == 15 or m2_type_now == 15:    ### Massless Supernova
        last_state = 12
else :
    last_state = 13

f2.write(f"{m1} {p} {sep_12_gyr} {m1_type_now} {m2_type_now} {last_state}\n")
# Out:
# 0.0 1.0
# 0.0 1.0
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[18], line 77
#      74 else :
#      75      case = 5 # any other state
# ---> 77 f1.write(f"{m1} {p} {case} {donar_state}\n")
#      79 # ---------------------------------------------12 Gyr -------------------------------------------------------------------------
#      81 subset_after_twelve_gyr = df[df["Time"] > 12000]  ### get subset where time is more than 12 Gyr
#
# NameError: name 'f1' is not defined

# %%
m1 = 13.4896  # 22.4827
m2 = m1/0.6
p = 2511.886431509582

print(m2)

content = f"""{m1}  {m2}    13700 {p}  1 1 0.02 0.0
0.5 0.0 1.0 3.0 0.5
0 1 0 1 0 2 3.0 29769
0.001 0.01 0.02
0.0 0.125 1.0 1.5 0.001 10.0 -1.0
1
"""

with open("binary.in", "w") as f:
    f.write(content)

# !/home/poornima/Documents/BSE_METISSE_project/bse_metisse


# ------------------- Read the file and assign column names -------------------------------------------
path = "/home/poornima/Documents/BSE_METISSE_project/output_binary/"
m1_str = f"{int(m1 * 100):05d}"
m2_str  = f"{int(m2 * 100):05d}"
file_name = f"{m1_str}M_{m2_str}M.dat"        ## file_name = "00200M_00100M.dat"
full_path = os.path.join(path, file_name)

data = np.loadtxt(full_path) 

# Remove the last row
data = data[:-1, :]

# Define the column names
columns = [
    "Time",
    "stellar_type_1","stellar_type_2","initial_mass_1","initial_mass_2", "current_mass_1","current_mass_2","log10_r_1","log10_r_2",
    "R1/ROL1","R2/ROL2","log10_L_1","log10_L_2",
    "spin_1","spin_2","mass_loss_rate_1","mass_loss_rate_2","convective_envelope_mass_1","convective_envelope_mass_2",
    "envelope_radius_1","envelope_radius_2","sep_Rsun","ecc"]
    
df = pd.DataFrame(data, columns=columns)

df["log10_T_eff_1"] = 3 + 0.25 * (np.log10(1130) + df["log10_L_1"] - 2 * df["log10_r_1"])
    
    
df["log10_T_eff_2"] = 3 + 0.25 * (np.log10(1130) + df["log10_L_2"] - 2 * df["log10_r_2"])

data3 = {
    "m1": m1,
    "m2": m2,
    "p": p,
    "log_L_1": df["log10_L_1"].tolist(),
    "log_T_eff_1": df["log10_T_eff_1"].tolist(),
    "log_L_2": df["log10_L_2"].tolist(),
    "log_T_eff_2": df["log10_T_eff_2"].tolist()
}

with open("tryf3.json", "w") as f3:
    json.dump(data3, f3, indent=2)

# %%
with open("tryf3.json") as f:
    data3 = json.load(f)

L1 = data3["log_L_1"]
T1 = data3["log_T_eff_1"]
L2 = data3["log_L_2"]
T2 = data3["log_T_eff_2"]

# %%
fig, axes = plt.subplots(1, 2, figsize=(18, 7))
ax1, ax2 = axes  # primary = left, secondary = right





# ----------------------------
# Primary star (R1/ROL1)
# ----------------------------
ax1.scatter(
    T1, 
    L1, 
    
    s=4
)
# ax1.set_xlim(xmin=0.0, xmax=x_max)
# ax1.set_ylim(ymin=0.0, ymax=1)
#ax1.plot(df["log10Teff_1"], df["log10_L_1"], lw=0.5, color='black', linestyle='--', zorder=-1)
ax1.set_xlabel('Log T_eff (K)',fontsize=20)
ax1.set_ylabel(r'Log (L/L$_\odot$)', fontsize=20)
ax1.invert_xaxis()
ax1.set_title('Hertzsprung–Russell diagram',fontsize=20)

# ----------------------------
# Secondary star (R2/ROL2)
# ----------------------------
ax2.scatter(
    T2, 
    L2, 
     
    s=4
)
#ax2.set_xlim(xmin=0.0, xmax=x_max)
#ax2.plot(df["log10Teff_2"], df["log10_L_2"], lw=0.5, color='black',linestyle='--', zorder=-1)
ax2.set_xlabel('Log T_eff (K)',fontsize=20)
ax2.set_ylabel(r'Log (L/L$_\odot$)', fontsize=20)
ax2.invert_xaxis()
ax2.set_title('Hertzsprung–Russell diagram',fontsize=20)



y0 = 0.15
dy = 0.04



fig.subplots_adjust(right=0.8)  # leave space for legend
plt.show()

# img_title = "HR_diag"


# save_name = f"{base_name}_{img_title}.png"
# save_dir = "./output_plots/"
# save_path = os.path.join(save_dir, save_name)

# fig.savefig(save_path, dpi=300, bbox_inches="tight")

# %%
mass = [10,  10.23292992] 

period = [1.00000000e+00, 1.25892541e+00]

with open("tryf3.jsonl", "w") as f3:
    for m1 in mass:
        for p in period:
    
            m2 = m1/0.6
            
            content = f"""{m1}  {m2}    13700 {p}  1 1 0.02 0.0
            0.5 0.0 1.0 3.0 0.5
            0 1 0 1 0 2 3.0 29769
            0.001 0.01 0.02
            0.0 0.125 1.0 1.5 0.001 10.0 -1.0
            1
            """
            
            with open("binary.in", "w") as f:
                f.write(content)
            
            # !/home/poornima/Documents/BSE_METISSE_project/bse_metisse
            
            
            # ------------------- Read the file and assign column names -------------------------------------------
            path = "/home/poornima/Documents/BSE_METISSE_project/output_binary/"
            m1_str = f"{int(m1 * 100):05d}"
            m2_str  = f"{int(m2 * 100):05d}"
            file_name = f"{m1_str}M_{m2_str}M.dat"        ## file_name = "00200M_00100M.dat"
            full_path = os.path.join(path, file_name)
            
            data = np.loadtxt(full_path) 
            
            # Remove the last row
            data = data[:-1, :]
            
            # Define the column names
            columns = [
                "Time",
                "stellar_type_1","stellar_type_2","initial_mass_1","initial_mass_2", "current_mass_1","current_mass_2","log10_r_1","log10_r_2",
                "R1/ROL1","R2/ROL2","log10_L_1","log10_L_2",
                "spin_1","spin_2","mass_loss_rate_1","mass_loss_rate_2","convective_envelope_mass_1","convective_envelope_mass_2",
                "envelope_radius_1","envelope_radius_2","sep_Rsun","ecc"]
                
            df = pd.DataFrame(data, columns=columns)
            
            df["log10_T_eff_1"] = 3 + 0.25 * (np.log10(1130) + df["log10_L_1"] - 2 * df["log10_r_1"])
                
                
            df["log10_T_eff_2"] = 3 + 0.25 * (np.log10(1130) + df["log10_L_2"] - 2 * df["log10_r_2"])
            
            data3 = {
                "m1": m1,
                "m2": m2,
                "p": p,
                "log_L_1": df["log10_L_1"].tolist(),
                "log_T_eff_1": df["log10_T_eff_1"].tolist(),
                "log_L_2": df["log10_L_2"].tolist(),
                "log_T_eff_2": df["log10_T_eff_2"].tolist()
            }
            
            json.dump(data3, f3)
            f3.write("\n")

# %%
data = []

with open("new_data_3.jsonl", "r") as f:
    for line in f:
        data.append(json.loads(line))

# %%
print(len(data[0]["log_L_1"]))

# %%
mass = 10 ** np.arange(np.log10(10), np.log10(40), 0.01)
print(len(mass))
print(mass)

mass_n = 10 ** np.arange(np.log10(15.13561248), np.log10(40), 0.01)

print(mass_n)
print(len(mass_n))
# Out:
# 61
# [10.         10.23292992 10.47128548 10.71519305 10.96478196 11.22018454
#  11.48153621 11.74897555 12.02264435 12.30268771 12.58925412 12.88249552
#  13.18256739 13.48962883 13.80384265 14.12537545 14.45439771 14.79108388
#  15.13561248 15.48816619 15.84893192 16.21810097 16.59586907 16.98243652
#  17.37800829 17.7827941  18.19700859 18.62087137 19.05460718 19.498446
#  19.95262315 20.41737945 20.89296131 21.3796209  21.87761624 22.38721139
#  22.90867653 23.44228815 23.98832919 24.54708916 25.11886432 25.70395783
#  26.30267992 26.91534804 27.54228703 28.18382931 28.84031503 29.51209227
#  30.1995172  30.90295433 31.6227766  32.35936569 33.11311215 33.88441561
#  34.67368505 35.48133892 36.30780548 37.15352291 38.01893963 38.9045145
#  39.81071706]
# [15.13561248 15.48816618 15.84893192 16.21810097 16.59586907 16.98243652
#  17.37800828 17.7827941  18.19700858 18.62087136 19.05460717 19.49844599
#  19.95262314 20.41737944 20.8929613  21.37962089 21.87761623 22.38721138
#  22.90867652 23.44228815 23.98832918 24.54708915 25.11886431 25.70395782
#  26.30267991 26.91534803 27.54228703 28.1838293  28.84031502 29.51209226
#  30.1995172  30.90295432 31.62277659 32.35936568 33.11311214 33.8844156
#  34.67368504 35.48133891 36.30780547 37.1535229  38.01893962 38.90451449
#  39.81071704]
# 43

# %%
mass = 10 ** np.arange(np.log10(10), np.log10(40), 0.01)
print(mass)

mass = mass[18 :]
print(mass)
# Out:
# [10.         10.23292992 10.47128548 10.71519305 10.96478196 11.22018454
#  11.48153621 11.74897555 12.02264435 12.30268771 12.58925412 12.88249552
#  13.18256739 13.48962883 13.80384265 14.12537545 14.45439771 14.79108388
#  15.13561248 15.48816619 15.84893192 16.21810097 16.59586907 16.98243652
#  17.37800829 17.7827941  18.19700859 18.62087137 19.05460718 19.498446
#  19.95262315 20.41737945 20.89296131 21.3796209  21.87761624 22.38721139
#  22.90867653 23.44228815 23.98832919 24.54708916 25.11886432 25.70395783
#  26.30267992 26.91534804 27.54228703 28.18382931 28.84031503 29.51209227
#  30.1995172  30.90295433 31.6227766  32.35936569 33.11311215 33.88441561
#  34.67368505 35.48133892 36.30780548 37.15352291 38.01893963 38.9045145
#  39.81071706]
# [15.13561248 15.48816619 15.84893192 16.21810097 16.59586907 16.98243652
#  17.37800829 17.7827941  18.19700859 18.62087137 19.05460718 19.498446
#  19.95262315 20.41737945 20.89296131 21.3796209  21.87761624 22.38721139
#  22.90867653 23.44228815 23.98832919 24.54708916 25.11886432 25.70395783
#  26.30267992 26.91534804 27.54228703 28.18382931 28.84031503 29.51209227
#  30.1995172  30.90295433 31.6227766  32.35936569 33.11311215 33.88441561
#  34.67368505 35.48133892 36.30780548 37.15352291 38.01893963 38.9045145
#  39.81071706]

# %%
mass = 10 ** np.arange(np.log10(10), np.log10(40), 0.01)
mass = mass[18:]  ### because we need masses larger than 15

print(mass)

mass_groups = np.array_split(mass, 22)  ## Divide mass list into 6 groups

print(mass_groups)
# Out:
# [15.13561248 15.48816619 15.84893192 16.21810097 16.59586907 16.98243652
#  17.37800829 17.7827941  18.19700859 18.62087137 19.05460718 19.498446
#  19.95262315 20.41737945 20.89296131 21.3796209  21.87761624 22.38721139
#  22.90867653 23.44228815 23.98832919 24.54708916 25.11886432 25.70395783
#  26.30267992 26.91534804 27.54228703 28.18382931 28.84031503 29.51209227
#  30.1995172  30.90295433 31.6227766  32.35936569 33.11311215 33.88441561
#  34.67368505 35.48133892 36.30780548 37.15352291 38.01893963 38.9045145
#  39.81071706]
# [array([15.13561248, 15.48816619]), array([15.84893192, 16.21810097]), array([16.59586907, 16.98243652]), array([17.37800829, 17.7827941 ]), array([18.19700859, 18.62087137]), array([19.05460718, 19.498446  ]), array([19.95262315, 20.41737945]), array([20.89296131, 21.3796209 ]), array([21.87761624, 22.38721139]), array([22.90867653, 23.44228815]), array([23.98832919, 24.54708916]), array([25.11886432, 25.70395783]), array([26.30267992, 26.91534804]), array([27.54228703, 28.18382931]), array([28.84031503, 29.51209227]), array([30.1995172 , 30.90295433]), array([31.6227766 , 32.35936569]), array([33.11311215, 33.88441561]), array([34.67368505, 35.48133892]), array([36.30780548, 37.15352291]), array([38.01893963, 38.9045145 ]), array([39.81071706])]

# %%
print(mass_groups[21])
# Out:
# [39.81071706]
