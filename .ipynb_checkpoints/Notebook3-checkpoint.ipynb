# %%
m1 = 2.0
m2 = 1.0
p = 100

content = f"""{m1}  {m2}    13700 {p}  1 1 0.02 0.0
0.5 0.0 1.0 3.0 0.5
0 1 0 1 0 2 3.0 29769
0.001 0.01 0.02
0.0 0.125 1.0 1.5 0.001 10.0 -1.0
1
"""

with open("binary.in", "w") as f:
    f.write(content)

# %%
# !/home/poornima/Documents/BSE_METISSE_project/bse_metisse
# Out:
# At line 97 of file ../src/bse.f (unit = 22, file = 'binary.in')
# Fortran runtime error: Bad real number in item 1 of list input
#
# Error termination. Backtrace:
# #0  0x7157c3423960 in ???
# #1  0x7157c34244d9 in ???
# #2  0x7157c342510f in ???
# #3  0x7157c36701b6 in ???
# #4  0x7157c36715fd in ???
# #5  0x7157c36722aa in ???
# #6  0x5661645c55d9 in bse
# 	at ../src/bse.f:97
# #7  0x5661645c53de in main
# 	at ../src/bse.f:242
