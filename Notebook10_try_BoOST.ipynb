# %% [markdown]
# # Run 2 systems for BoOST . Used Z= 0.02 for BoOST ( But should use Z = 0.008 for BoOST)

# %%
import numpy as np
import matplotlib as mpl
import matplotlib.pyplot as plt
import os
from pathlib import Path
import pandas as pd
from IPython.display import clear_output
import time
import json

# %%
def read_file(m1,m2):
    # ------------------- Read the file and assign column names -------------------------------------------
    path = "/home/poornima/Documents/BSE_METISSE_project/output_binary/"
    m1_str = f"{int(m1 * 100):05d}"
    m2_str  = f"{int(m2 * 100):05d}"
    file_name = f"{m1_str}M_{m2_str}M.dat"        ## file_name = "00200M_00100M.dat"
    full_path = os.path.join(path, file_name)

    return (full_path)

def make_df(full_path):
    data = np.loadtxt(full_path) 

    # Remove the last row
    data = data[:-1, :]
    
    # Define the column names
    columns = [
        "Time",
        "stellar_type_1","stellar_type_2","initial_mass_1","initial_mass_2", "current_mass_1","current_mass_2","log10_r_1","log10_r_2",
        "R1/ROL1","R2/ROL2","log10_L_1","log10_L_2",
        "spin_1","spin_2","mass_loss_rate_1","mass_loss_rate_2","convective_envelope_mass_1","convective_envelope_mass_2",
        "envelope_radius_1","envelope_radius_2","sep_Rsun","ecc"]
        
    df = pd.DataFrame(data, columns=columns)

    return(df)

# %%
# mass = 10 ** np.arange(np.log10(10), np.log10(40), 0.01)
# period = 10 ** np.arange(np.log10(1), np.log10(10001), 0.1)

mass = [15.488166]
period = [1.00000000e+00]
i = 0


    
for m1 in mass:
    for p in period:
        m2 = m1 * 0.6      # m2/m1 = 0.6
        #m2 =  9.2929
        
        print(i)
        
        content = f"""{m1}  {m2}    13700 {p}  1 1 0.0088 0.0
        0.5 0.0 1.0 3.0 0.5
        0 1 0 1 0 2 3.0 29769
        0.001 0.01 0.02
        0.0 0.125 1.0 1.5 0.001 10.0 -1.0
        1
        """
        i = i+1
        
        with open("binary.in", "w") as f:
            f.write(content)
        
        # !/home/poornima/Documents/BSE_METISSE_project/bse_metisse  ### Run BSE
    
        time.sleep(30.0)
    
        full_path = read_file(m1,m2)

        df = make_df(full_path)
    
        sep = df["sep_Rsun"].iloc[-5]

        R1_ROL1 = df["R1/ROL1"].iloc[-5]

        R2_ROL2 = df["R2/ROL2"].iloc[-5]

        print(m1,m2,sep,R1_ROL1,R2_ROL2)
# Out:
# 0
#
#  METALLICITY_DIR: /home/poornima/Documents/BSE_METISSE_project/BoOST/
#  METALLICITY_DIR_HE: /home/poornima/Documents/BSE_METISSE_project/sample_tracks_solarZ/Helium
#  Input Z is :  8.80000E-03
#  Reading naked helium star tracks
#  Found matching Z_files   2.00000E-02
#  Found           33  tracks.
#  Minimum initial mass    0.4
#  Maximum initial mass  148.8
#  Reading main (hydrogen star) tracks
#  Found matching Z_files   8.00000E-03
#  Found           10  tracks.
#  Minimum initial mass    9.0
#  Maximum initial mass  498.8
#       TIME      M1       M2   K1 K2        SEP    ECC  R1/ROL1 R2/ROL2  TYPE
#      0.0000   15.488    9.293  1  1       12.265  0.00   0.913   0.863  INITIAL
#      1.3444   15.513    9.201  1  1       11.703  0.00   1.001   0.908  BEG RCHE
#      1.3694      NaN      NaN  1  1          NaN  0.00     NaN     NaN  END RCHE
#     11.9515      NaN      NaN  1  1          NaN   NaN     NaN     NaN  BEG BSS
#     11.9523      NaN      NaN  2  1          NaN   NaN     NaN     NaN  KW CHNGE
#     12.0281      NaN      NaN  4  1          NaN   NaN     NaN     NaN  KW CHNGE
#     12.9164    1.361      NaN 13  1          NaN  0.00     NaN     NaN  KW CHNGE
#     12.9164    1.361      NaN 13  1          NaN   NaN     NaN     NaN  BEG SYMB
#     27.1133    1.428      NaN 13  2          NaN   NaN     NaN     NaN  KW CHNGE
#     27.2949    1.431      NaN 13  4          NaN   NaN     NaN     NaN  KW CHNGE
#     29.2893    1.843    1.260 13 13        0.000  0.00InfinityInfinity  KW CHNGE
#  13700.0000    1.843    1.260 13 13          NaN   NaN     NaN     NaN  MAX TIME
#
# Note: The following floating-point exceptions are signalling: IEEE_INVALID_FLAG IEEE_DIVIDE_BY_ZERO IEEE_OVERFLOW_FLAG IEEE_UNDERFLOW_FLAG IEEE_DENORMAL
# 15.488166 9.2928996 11.49 1.0197 0.9248

# %%
print(i)

# %%
#          0 - deeply or fully convective low mass MS star
# c        1 - Main Sequence star
# c        2 - Hertzsprung Gap
# c        3 - First Giant Branch
# c        4 - Core Helium Burning
# c        5 - First Asymptotic Giant Branch
# c        6 - Second Asymptotic Giant Branch
# c        7 - Main Sequence Naked Helium star
# c        8 - Hertzsprung Gap Naked Helium star
# c        9 - Giant Branch Naked Helium star
# c       10 - Helium White Dwarf
# c       11 - Carbon/Oxygen White Dwarf
# c       12 - Oxygen/Neon White Dwarf
# c       13 - Neutron Star
# c       14 - Black Hole
# c       15 - Massless Supernova
# c
