# %%
import numpy as np
import matplotlib as mpl
import matplotlib.pyplot as plt
import os
from pathlib import Path
import pandas as pd
from IPython.display import clear_output
import time
import json

# %%
def read_file(m1,m2):
    # ------------------- Read the file and assign column names -------------------------------------------
    path = "/home/poornima/Documents/BSE_METISSE_project/output_binary/"
    m1_str = f"{int(m1 * 100):05d}"
    m2_str  = f"{int(m2 * 100):05d}"
    file_name = f"{m1_str}M_{m2_str}M.dat"        ## file_name = "00200M_00100M.dat"
    full_path = os.path.join(path, file_name)

    return (full_path)

def make_df(full_path):
    data = np.loadtxt(full_path) 

    # Remove the last row
    data = data[:-1, :]
    
    # Define the column names
    columns = [
        "Time",
        "stellar_type_1","stellar_type_2","initial_mass_1","initial_mass_2", "current_mass_1","current_mass_2","log10_r_1","log10_r_2",
        "R1/ROL1","R2/ROL2","log10_L_1","log10_L_2",
        "spin_1","spin_2","mass_loss_rate_1","mass_loss_rate_2","convective_envelope_mass_1","convective_envelope_mass_2",
        "envelope_radius_1","envelope_radius_2","sep_Rsun","ecc"]
        
    df = pd.DataFrame(data, columns=columns)

    return(df)

# %%
# mass = 10 ** np.arange(np.log10(10), np.log10(40), 0.01)
# period = 10 ** np.arange(np.log10(1), np.log10(10001), 0.1)

mass = [15.13561248, 15.48816619]
period = [1.00000000e+00, 1.25892541e+00]
i = 0


    
for m1 in mass:
    for p in period:
        m2 = m1 * 0.6      # m2/m1 = 0.6
        
        print(i)
        
        content = f"""{m1}  {m2}    13700 {p}  1 1 0.02 0.0
        0.5 0.0 1.0 3.0 0.5
        0 1 0 1 0 2 3.0 29769
        0.001 0.01 0.02
        0.0 0.125 1.0 1.5 0.001 10.0 -1.0
        1
        """
        i = i+1
        
        with open("binary.in", "w") as f:
            f.write(content)
        
        # !/home/poornima/Documents/BSE_METISSE_project/bse_metisse  ### Run BSE
    
        time.sleep(30.0)
    
        full_path = read_file(m1,m2)

        df = make_df(full_path)
    
        sep = df["sep_Rsun"].iloc[-5]

        R1_ROL1 = df["R1/ROL1"].iloc[-5]

        R2_ROL2 = df["R2/ROL2"].iloc[-5]

        print(m1,m2,sep,R1_ROL1,R2_ROL2)
# Out:
# 0
#
#  METALLICITY_DIR: /home/poornima/Documents/BSE_METISSE_project/sample_tracks_solarZ/Hydrogen
#  METALLICITY_DIR_HE: /home/poornima/Documents/BSE_METISSE_project/sample_tracks_solarZ/Helium
#  Input Z is :  2.00000E-02
#  Reading naked helium star tracks
#  Found matching Z_files   2.00000E-02
#  Found           33  tracks.
#  Minimum initial mass    0.4
#  Maximum initial mass  148.8
#  Reading main (hydrogen star) tracks
#  Found matching Z_files   2.00000E-02
#  Found           85  tracks.
#  Minimum initial mass    0.1
#  Maximum initial mass  299.3
#       TIME      M1       M2   K1 K2        SEP    ECC  R1/ROL1 R2/ROL2  TYPE
#      0.0000   15.136    9.081  1  1       12.171  0.00   0.955   0.905  INITIAL
#      0.7031   15.132    9.080  1  1       12.022  0.00   1.000   0.930  BEG RCHE
#      3.8496   14.958    9.227  1  1       11.823  0.00   1.155   1.000  CONTACT
#      3.8496   24.185    9.227  1 15        0.000  0.00   0.000  -1.000  COELESCE
#      7.2728   23.738    0.000  1 15        0.000 -1.00   0.000  -1.000  BEG BSS
#     10.9508   21.543    0.000  2 15        0.000 -1.00   0.000  -1.000  KW CHNGE
#     10.9604   21.500    0.000  4 15        0.000 -1.00   0.000  -1.000  KW CHNGE
#     11.4684   11.543    0.000  7 15        0.000 -1.00   0.000  -1.000  KW CHNGE
#     11.5520   10.614    0.000  8 15        0.000 -1.00   0.000  -1.000  KW CHNGE
#     11.5583    7.892    0.000 14 15        0.000 -1.00   0.000  -1.000  KW CHNGE
#  13700.0000    7.892    0.000 14 15        0.000 -1.00   0.000  -1.000  MAX TIME
#
# Note: The following floating-point exceptions are signalling: IEEE_INVALID_FLAG
# 15.13561248 9.081367488 0.0 0.0001 -1.0
# 1
#
#  METALLICITY_DIR: /home/poornima/Documents/BSE_METISSE_project/sample_tracks_solarZ/Hydrogen
#  METALLICITY_DIR_HE: /home/poornima/Documents/BSE_METISSE_project/sample_tracks_solarZ/Helium
#  Input Z is :  2.00000E-02
#  Reading naked helium star tracks
#  Found matching Z_files   2.00000E-02
#  Found           33  tracks.
#  Minimum initial mass    0.4
#  Maximum initial mass  148.8
#  Reading main (hydrogen star) tracks
#  Found matching Z_files   2.00000E-02
#  Found           85  tracks.
#  Minimum initial mass    0.1
#  Maximum initial mass  299.3
#       TIME      M1       M2   K1 K2        SEP    ECC  R1/ROL1 R2/ROL2  TYPE
#      0.0000   15.136    9.081  1  1       14.190  0.00   0.819   0.776  INITIAL
#      4.3358   15.105    9.074  1  1       13.967  0.00   1.000   0.851  BEG RCHE
#      8.1428   13.717   10.415  1  1       12.773  0.00   1.369   1.000  CONTACT
#      8.1428   24.131   10.415  1 15        0.000  0.00   0.000  -1.000  COELESCE
#      8.1428   24.131    0.000  1 15        0.000 -1.00   1.300  -1.000  BEG BSS
#     14.9810   21.394    0.000  2 15        0.000 -1.00   0.000  -1.000  KW CHNGE
#     14.9904   21.352    0.000  4 15        0.000 -1.00   0.000  -1.000  KW CHNGE
#     15.4325   11.749    0.000  7 15        0.000 -1.00   0.000  -1.000  KW CHNGE
#     15.6822    8.448    0.000  8 15        0.000 -1.00   0.000  -1.000  KW CHNGE
#     15.6900    4.810    0.000 14 15        0.000 -1.00   0.000  -1.000  KW CHNGE
#  13700.0000    4.810    0.000 14 15        0.000 -1.00   0.000  -1.000  MAX TIME
#
# Note: The following floating-point exceptions are signalling: IEEE_INVALID_FLAG
# 15.13561248 9.081367488 0.0 0.0001 -1.0
# 2
#
#  METALLICITY_DIR: /home/poornima/Documents/BSE_METISSE_project/sample_tracks_solarZ/Hydrogen
#  METALLICITY_DIR_HE: /home/poornima/Documents/BSE_METISSE_project/sample_tracks_solarZ/Helium
#  Input Z is :  2.00000E-02
#  Reading naked helium star tracks
#  Found matching Z_files   2.00000E-02
#  Found           33  tracks.
#  Minimum initial mass    0.4
#  Maximum initial mass  148.8
#  Reading main (hydrogen star) tracks
#  Found matching Z_files   2.00000E-02
#  Found           85  tracks.
#  Minimum initial mass    0.1
#  Maximum initial mass  299.3
#       TIME      M1       M2   K1 K2        SEP    ECC  R1/ROL1 R2/ROL2  TYPE
#      0.0000   15.488    9.293  1  1       12.265  0.00   0.960   0.910  INITIAL
#      0.5419   15.485    9.292  1  1       12.105  0.00   1.000   0.933  BEG RCHE
#      3.4722   15.337    9.411  1  1       11.934  0.00   1.147   1.000  CONTACT
#      3.4722   24.748    9.411  1 15        0.000  0.00   0.000  -1.000  COELESCE
#      7.1226   24.203    0.000  1 15        0.000 -1.00   0.000  -1.000  BEG BSS
#     10.4352   21.940    0.000  2 15        0.000 -1.00   0.000  -1.000  KW CHNGE
#     10.4444   21.897    0.000  4 15        0.000 -1.00   0.000  -1.000  KW CHNGE
#     10.9336   11.858    0.000  7 15        0.000 -1.00   0.000  -1.000  KW CHNGE
#     11.0159   10.933    0.000  8 15        0.000 -1.00   0.000  -1.000  KW CHNGE
#     11.0221    9.780    0.000 14 15        0.000 -1.00   0.000  -1.000  KW CHNGE
#  13700.0000    9.780    0.000 14 15        0.000 -1.00   0.000  -1.000  MAX TIME
#
# Note: The following floating-point exceptions are signalling: IEEE_INVALID_FLAG
# 15.48816619 9.292899713999999 0.0 0.0001 -1.0
# 3
#
#  METALLICITY_DIR: /home/poornima/Documents/BSE_METISSE_project/sample_tracks_solarZ/Hydrogen
#  METALLICITY_DIR_HE: /home/poornima/Documents/BSE_METISSE_project/sample_tracks_solarZ/Helium
#  Input Z is :  2.00000E-02
#  Reading naked helium star tracks
#  Found matching Z_files   2.00000E-02
#  Found           33  tracks.
#  Minimum initial mass    0.4
#  Maximum initial mass  148.8
#  Reading main (hydrogen star) tracks
#  Found matching Z_files   2.00000E-02
#  Found           85  tracks.
#  Minimum initial mass    0.1
#  Maximum initial mass  299.3
#       TIME      M1       M2   K1 K2        SEP    ECC  R1/ROL1 R2/ROL2  TYPE
#      0.0000   15.488    9.293  1  1       14.300  0.00   0.823   0.780  INITIAL
#      4.0704   15.455    9.285  1  1       14.062  0.00   1.001   0.856  BEG RCHE
#      7.7880   14.135   10.551  1  1       12.918  0.00   1.363   1.001  CONTACT
#      7.7880   24.687   10.551  1 15        0.000  0.00   0.000  -1.000  COELESCE
#      7.7880   24.687    0.000  1 15        0.000 -1.00   1.297  -1.000  BEG BSS
#     14.4774   21.772    0.000  2 15        0.000 -1.00   0.000  -1.000  KW CHNGE
#     14.4863   21.729    0.000  4 15        0.000 -1.00   0.000  -1.000  KW CHNGE
#     14.9083   12.089    0.000  7 15        0.000 -1.00   0.000  -1.000  KW CHNGE
#     15.1754    8.401    0.000  8 15        0.000 -1.00   0.000  -1.000  KW CHNGE
#     15.1832    4.752    0.000 14 15        0.000 -1.00   0.000  -1.000  KW CHNGE
#  13700.0000    4.752    0.000 14 15        0.000 -1.00   0.000  -1.000  MAX TIME
#
# Note: The following floating-point exceptions are signalling: IEEE_INVALID_FLAG
# 15.48816619 9.292899713999999 0.0 0.0001 -1.0

# %%
print(i)
# Out:
# 4

# %%
#          0 - deeply or fully convective low mass MS star
# c        1 - Main Sequence star
# c        2 - Hertzsprung Gap
# c        3 - First Giant Branch
# c        4 - Core Helium Burning
# c        5 - First Asymptotic Giant Branch
# c        6 - Second Asymptotic Giant Branch
# c        7 - Main Sequence Naked Helium star
# c        8 - Hertzsprung Gap Naked Helium star
# c        9 - Giant Branch Naked Helium star
# c       10 - Helium White Dwarf
# c       11 - Carbon/Oxygen White Dwarf
# c       12 - Oxygen/Neon White Dwarf
# c       13 - Neutron Star
# c       14 - Black Hole
# c       15 - Massless Supernova
# c
